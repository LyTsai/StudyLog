# %%
import akshare as ak
import numpy as np
import pandas as pd

# %%
# 沪深300， 中证500， 红利ETF， 创业板ETF
pool_list = ['510300', '510500' '510880', '159915']
start_date = '20130914'
hist = ak.stock_zh_a_hist(symbol='000001', start_date='20130914', adjust='hfq')
hist
# Out:
#               日期       开盘       收盘       最高       最低      成交量           成交额  \
# 0     2013-09-16  1220.81  1218.93  1260.32  1169.08  1434366  1.874389e+09
# 1     2013-09-17  1214.23  1180.37  1234.92  1176.61   940026  1.224997e+09
# 2     2013-09-18  1176.61  1180.37  1199.18  1154.03   617003  7.868978e+08
# 3     2013-09-23  1181.31  1188.83  1197.30  1164.38   723795  9.286728e+08
# 4     2013-09-24  1186.95  1131.46  1187.89  1103.24  1456189  1.786488e+09
# ...          ...      ...      ...      ...      ...      ...           ...
# 2428  2023-09-08  2085.53  2083.91  2092.04  2077.41   479030  5.396250e+08
# 2429  2023-09-11  2088.79  2095.29  2105.04  2083.91   654486  7.417649e+08
# 2430  2023-09-12  2096.91  2085.53  2096.91  2080.66   495485  5.590585e+08
# 2431  2023-09-13  2087.16  2080.66  2092.04  2074.16   490218  5.517476e+08
# 2432  2023-09-14  2085.53  2087.16  2093.66  2080.66   551650  6.229061e+08
#
#         振幅   涨跌幅    涨跌额   换手率
# ...
