# %%
import numpy as np

# %%
operators = ['x', '/', '-', '+']
numbers = [5, 5, 5, 9]
value = 0
count = 0

# %%
while value != 24 and count < 2000:
  count += 1
  np.random.shuffle(numbers)
  for i in range(0, len(numbers)):
    number = numbers[i]
    if i == 0:
        express = str(number)
        value = number
        continue
    operator = np.random.choice(operators)
    if operator == '+':
      value += number
    elif operator == '-':
      value -= number
    elif operator == 'x':
      value *= number
    else:
      value /= number

    express += operator + str(number)

if value == 24: 
  print(express, count)  
else:
  print('Unvailable')
# Out:
# Unvailable
